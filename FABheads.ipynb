# %% [markdown]
# <a href="https://colab.research.google.com/github/TanujSinghRawat/FABHEAD_TEST/blob/main/FAB_heads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import *
# !pip install numpy-stl        #Importing a library that is not in Colaboratory

# %%
from stl import mesh

# %%
print("please upload the file ")                         
from google.colab import files
uploaded=files.upload()
# Out:
# please upload the file
#      <input type="file" id="files-b8a24e9e-497b-457f-8caa-345d6ace6a5a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8a24e9e-497b-457f-8caa-345d6ace6a5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving assignment.stl to assignment (1).stl

# %%
geometry_raw = mesh.Mesh.from_file('assignment.stl')
# Out:
# exception (0, "Cannot read normals (2:b'\\x15b')")

# %%
from mpl_toolkits import mplot3d
from matplotlib import pyplot

# %%
figure = pyplot.figure()
axes = mplot3d.Axes3D(figure)

axes.add_collection3d(mplot3d.art3d.Poly3DCollection(geometry_raw.vectors))
scale = geometry_raw.points.flatten()
axes.auto_scale_xyz(scale, scale, scale)

pyplot.show()
